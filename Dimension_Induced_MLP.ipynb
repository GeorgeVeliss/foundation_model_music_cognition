# %%
# Import libraries
# transformers: Provides access to pre-trained models like CLAP.
from transformers import ClapModel, AutoProcessor

# librosa: Used for audio analysis and loading audio files.
import librosa

# os: Provides a way to interact with the operating system, like navigating directories.
import os

import torch
import pandas as pd
import numpy as np

# %%
# Load CLAP model + processor
model = ClapModel.from_pretrained("laion/clap-htsat-unfused")
processor = AutoProcessor.from_pretrained("laion/clap-htsat-unfused")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/615M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/614M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/384 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]

# %%
#Small test to print all the parameters of CLAP
print('total number of CLAP\'s parameters:', sum(p.numel() for p in model.parameters()))
# Out:
# total number of CLAP's parameters: 153492890

# %%
#Calculating the size of the data of all the parameters
param_size = 0 # We are using a for loop to add size of all parameters os initialised as 0 at the beginning

for param in model.parameters():
    #In increments we are adding the size of each parameter given by formula
    #param.nelement() is giving total number of elements in each parameter
    #param.element_size() is giving size of element in bytes
    param_size += param.nelement() * param.element_size()

#Buffers are tensors but not learnable parameters but still take up space
buffer_size = 0
for buffer in model.buffers():
    buffer_size += buffer.nelement() * buffer.element_size()

#Total size adds buffer size and parameter size
#Converted into MB
size_all_mb = (param_size + buffer_size) / 1024**2
print('CLAP model size: {:.3f}MB'.format(size_all_mb))
# Out:
# CLAP model size: 585.912MB

# %%
#This section is to convert the uploaded zip files into folders
import zipfile

# Define the paths to your zip files
zip_files = ["Exp1.zip", "Exp2.zip", "Analysis.zip"]

# Define the directory where you want to extract the files
extract_dir = "/content/" # You can change this if you want to extract elsewhere

# Create the extraction directory if it doesn't exist
os.makedirs(extract_dir, exist_ok=True)

# Extract each zip file
for zip_file in zip_files:
    if os.path.exists(zip_file):
        with zipfile.ZipFile(zip_file, 'r') as zip_ref:
            zip_ref.extractall(extract_dir)
        print(f"Extracted {zip_file} to {extract_dir}")
    else:
        print(f"Erro r: {zip_file} not found.")
# Out:
# Extracted Exp1.zip to /content/
# Extracted Exp2.zip to /content/
# Extracted Analysis.zip to /content/

# %% [markdown]
# # Process audio

# %%
audio_stimuli = []
stimuli_path = "/content/Exp1/Stimuli/"  #/content/Exp2/Stimuli/ if we are running experiment 2

#This section adds all the audio waveforms into the list audio_stimuli
for file in sorted(os.listdir(stimuli_path)):
    if file.endswith(".wav"):
        wav_path = os.path.join(stimuli_path, file)
        #Clap has already been trained on a sample rate of 48,000 so we should use what it knows already
        print(wav_path)
        audio, sample_rate = librosa.load(wav_path, sr=48000)
        audio_stimuli.append(audio)
# Out:
# /content/Exp1/Stimuli/01_B_CTu_1.wav
# /content/Exp1/Stimuli/02_B_CTu_2.wav
# /content/Exp1/Stimuli/03_B_Tu_3.wav
# /content/Exp1/Stimuli/04_B_Tu_4.wav
# /content/Exp1/Stimuli/05_B_CTb_1.wav
# /content/Exp1/Stimuli/06_B_CTb_2.wav
# /content/Exp1/Stimuli/07_B_BTb_3.wav
# /content/Exp1/Stimuli/08_B_TTb_4.wav
# /content/Exp1/Stimuli/09_B_Ho_3.wav
# /content/Exp1/Stimuli/10_B_Ho_4.wav
# /content/Exp1/Stimuli/11_B_Ho_5.wav
# /content/Exp1/Stimuli/12_B_Tr_4.wav
# /content/Exp1/Stimuli/13_B_PTr_5.wav
# /content/Exp1/Stimuli/14_B_PTr_6.wav
# /content/Exp1/Stimuli/15_W_CBa_1.wav
# /content/Exp1/Stimuli/16_W_CBa_2.wav
# /content/Exp1/Stimuli/17_W_Ba_3.wav
# /content/Exp1/Stimuli/18_W_Ba_4.wav
# /content/Exp1/Stimuli/19_W_BCl_2.wav
# /content/Exp1/Stimuli/20_W_BCl_3.wav
# /content/Exp1/Stimuli/21_W_ClB_4.wav
# /content/Exp1/Stimuli/22_W_ClB_5.wav
# /content/Exp1/Stimuli/23_W_ClB_6.wav
# /content/Exp1/Stimuli/24_W_Ob_4.wav
# /content/Exp1/Stimuli/25_W_Ob_5.wav
# /content/Exp1/Stimuli/26_W_EH_4.wav
# /content/Exp1/Stimuli/27_W_EH_5.wav
# /content/Exp1/Stimuli/28_W_AFl_4.wav
# /content/Exp1/Stimuli/29_W_Fl_5.wav
# /content/Exp1/Stimuli/30_W_Fl_6.wav
# /content/Exp1/Stimuli/31_S_Ha_1.wav
# /content/Exp1/Stimuli/32_S_Ha_3.wav
# /content/Exp1/Stimuli/33_S_Ha_5.wav
# /content/Exp1/Stimuli/34_S_Ha_6.wav
# /content/Exp1/Stimuli/35_S_Ha_7.wav
# /content/Exp1/Stimuli/36_S_VC_2.wav
# /content/Exp1/Stimuli/37_S_VC_3.wav
# /content/Exp1/Stimuli/38_S_VC_4.wav
# /content/Exp1/Stimuli/39_S_Vl_5.wav
# /content/Exp1/Stimuli/40_S_Vl_6.wav
# /content/Exp1/Stimuli/41_S_Vl_7.wav
# /content/Exp1/Stimuli/42_P_Tmp_2.wav
# /content/Exp1/Stimuli/43_P_Tmp_3.wav
# /content/Exp1/Stimuli/44_P_Go_3.wav
# /content/Exp1/Stimuli/45_P_Go_5.wav
# /content/Exp1/Stimuli/46_P_Ce_3.wav
# /content/Exp1/Stimuli/47_P_Ce_5.wav
# /content/Exp1/Stimuli/48_P_Ce_7.wav
# /content/Exp1/Stimuli/49_P_Gsp_6.wav
# /content/Exp1/Stimuli/50_P_Gsp_7.wav
# /content/Exp1/Stimuli/51_P_Xyl_5.wav
# /content/Exp1/Stimuli/52_P_Xyl_6.wav
# /content/Exp1/Stimuli/53_P_Vib_4.wav
# /content/Exp1/Stimuli/54_P_Vib_6.wav
# /content/Exp1/Stimuli/55_P_Cro_6.wav
# /content/Exp1/Stimuli/56_P_Cro_7.wav
# /content/Exp1/Stimuli/57_S_VC_5.wav
# /content/Exp1/Stimuli/58_S_VC_6.wav
# /content/Exp1/Stimuli/59_S_Vl_4.wav

# %%
#verifcation if we opened correct file
print(audio_stimuli)
# Out:
# [array([-2.6257991e-05, -1.8168332e-05,  4.3254666e-05, ...,
#        -1.1775010e-05,  1.0805696e-06, -3.3297738e-08], dtype=float32), array([-2.1216942e-05, -4.7350541e-06,  1.5635709e-05, ...,
#         2.8016274e-08, -1.7804325e-08,  6.9179218e-09], dtype=float32), array([-9.8106102e-06,  1.1119668e-05, -3.5152134e-05, ...,
#        -3.4414730e-05, -1.3167290e-05,  4.1392400e-06], dtype=float32), array([-2.9096404e-06, -1.3023089e-05, -4.7573376e-06, ...,
#        -3.4261415e-05, -2.2727640e-05,  2.1467149e-06], dtype=float32), array([ 2.7754413e-06, -7.0806864e-06,  1.1189784e-05, ...,
#        -1.2227122e-06,  7.4793968e-07, -2.8134855e-07], dtype=float32), array([-6.7172846e-07,  5.4504471e-06, -5.0830917e-05, ...,
#        -1.6670765e-06,  1.9083664e-06,  0.0000000e+00], dtype=float32), array([ 1.6268901e-05, -3.3643319e-05,  2.5531041e-05, ...,
#        -3.3158278e-05, -2.5886366e-05,  7.7379474e-07], dtype=float32), array([ 6.1509754e-06,  2.7266901e-06, -4.9879025e-05, ...,
#        -1.2364532e-05,  1.1225065e-06,  2.1652534e-07], dtype=float32), array([-1.2935993e-05,  1.4063859e-05, -2.7317945e-05, ...,
#        -3.3172622e-05, -2.6103438e-05,  1.1196621e-06], dtype=float32), array([-9.1729271e-07, -1.8657744e-06,  1.6735030e-05, ...,
#        -1.2633650e-07,  8.2363364e-08, -3.1772089e-08], dtype=float32), array([ 1.5642452e-06, -1.5684513e-05,  5.7308625e-06, ...,
#        -3.3306424e-05, -2.5978612e-05,  1.0187714e-06], dtype=float32), array([-1.4188244e-07, -1.1887631e-06, -1.0004154e-05, ...,
#         1.3927917e-09, -7.9028268e-09,  1.2808009e-08], dtype=float32), array([-2.3093999e-05, -1.5143356e-05,  3.0004849e-05, ...,
#        -1.7431099e-05, -1.2769809e-05,  6.1251075e-07], dtype=float32), array([ 4.9721725e-06, -5.8993032e-06, -1.1843043e-05, ...,
#         4.1490927e-07, -2.1542128e-07,  3.6716585e-10], dtype=float32), array([ 2.3745356e-06,  7.4817785e-06, -1.1219506e-04, ...,
#        -3.3358068e-05, -2.5879415e-05,  8.9282264e-07], dtype=float32), array([-6.7608598e-06, -1.0303864e-05, -5.2730029e-06, ...,
#        -3.3248401e-05, -2.5959700e-05,  9.3755636e-07], dtype=float32), array([-1.5505837e-05, -2.5053794e-05, -2.7276579e-05, ...,
#        -3.2252331e-08,  3.2337393e-08, -2.7876080e-08], dtype=float32), array([-4.02149499e-06,  1.35382725e-05, -5.81804707e-05, ...,
#        -3.35259938e-05, -2.57072825e-05,  7.39930556e-07], dtype=float32), array([-9.4692405e-06, -1.1910475e-05,  2.8523089e-05, ...,
#         2.0197362e-08, -1.1829766e-07,  1.7319233e-07], dtype=float32), array([ 1.3681145e-05, -1.0639560e-05, -9.1507136e-06, ...,
#        -4.8083237e-08,  1.6149596e-07, -2.3570095e-07], dtype=float32), array([ 1.93218239e-05, -1.36855733e-05, -1.25411025e-05, ...,
#        -3.33269709e-05, -2.58431483e-05,  8.03901798e-07], dtype=float32), array([ 1.1897391e-06,  3.8232133e-06, -2.1643285e-05, ...,
#        -3.3487035e-05, -2.5532019e-05,  4.1968548e-07], dtype=float32), array([-1.5375304e-06, -4.4448614e-05,  1.0002783e-04, ...,
#        -1.6867387e-05, -1.2646784e-05,  1.1658483e-07], dtype=float32), array([-8.5098136e-06, -8.5966858e-06,  1.3324113e-04, ...,
#        -3.3542954e-05, -2.5779837e-05,  8.4104420e-07], dtype=float32), array([-1.4975831e-06, -1.0354467e-05, -5.6408942e-05, ...,
#        -3.5069341e-05, -2.5689718e-05,  1.3957066e-06], dtype=float32), array([-4.9591736e-06,  1.1500533e-05, -7.1624723e-05, ...,
#        -3.3086042e-05, -2.6053047e-05,  9.5778648e-07], dtype=float32), array([-1.9736967e-06,  1.4376342e-05, -6.6991321e-05, ...,
#        -3.3468517e-05, -2.5764055e-05,  7.8974176e-07], dtype=float32), array([-3.49356778e-05,  2.90082407e-05, -2.74524100e-05, ...,
#        -1.73511762e-05, -1.29619975e-05,  8.54821792e-07], dtype=float32), array([ 1.20731124e-06,  3.33978574e-06, -2.19408357e-05, ...,
#        -1.58046896e-05, -1.32447385e-05,  4.05460270e-07], dtype=float32), array([ 5.2861478e-06, -8.6107602e-06, -6.2180243e-07, ...,
#        -2.8420318e-05, -1.1905519e-05,  4.6386219e-07], dtype=float32), array([-1.2070618e-05,  5.7427264e-05,  6.6874112e-04, ...,
#        -3.3375905e-05, -2.5866180e-05,  8.8623193e-07], dtype=float32), array([-1.4080798e-05, -8.1257258e-06, -5.5979654e-06, ...,
#        -2.9986640e-09,  3.3114744e-09, -3.0950178e-09], dtype=float32), array([-4.1040945e-05,  1.7009290e-05, -8.9411951e-06, ...,
#        -2.8396807e-05, -1.1900271e-05,  4.3473818e-07], dtype=float32), array([-2.7460908e-05,  1.6825123e-05,  9.5203541e-07, ...,
#        -1.0646561e-06,  9.5897349e-07, -7.1181739e-07], dtype=float32), array([-4.2567085e-06,  1.1780801e-05, -4.4994329e-05, ...,
#        -2.3772202e-06,  2.6149251e-06,  0.0000000e+00], dtype=float32), array([ 1.0417866e-06,  4.3241780e-06, -3.5418303e-05, ...,
#        -3.3313034e-05, -2.5922975e-05,  9.2938672e-07], dtype=float32), array([-5.4652878e-06,  8.1074959e-06, -3.3808057e-05, ...,
#        -1.2596025e-05,  1.1936311e-07,  0.0000000e+00], dtype=float32), array([-3.2049084e-06,  3.4254479e-06, -3.3706492e-06, ...,
#        -3.3337714e-05, -2.5896838e-05,  9.0570347e-07], dtype=float32), array([-4.1151516e-06, -8.3583245e-08, -6.7558658e-06, ...,
#         5.9490787e-08,  4.4349392e-08, -1.2078635e-07], dtype=float32), array([-1.7325965e-05,  4.2624270e-06, -1.9190535e-05, ...,
#        -1.6755783e-05, -1.3085552e-05,  7.4324043e-07], dtype=float32), array([-1.2497098e-05,  9.0381409e-06, -3.2230755e-06, ...,
#        -6.9801325e-07,  9.3092694e-08,  2.5231279e-07], dtype=float32), array([ 3.6496756e-06, -2.0967007e-05,  1.5863217e-05, ...,
#        -3.3358985e-05, -2.5868532e-05,  8.7513001e-07], dtype=float32), array([-1.35920045e-05,  1.07345732e-05, -5.19257355e-06, ...,
#        -5.26332450e-11, -1.53351568e-11,  6.78667678e-11], dtype=float32), array([-2.4025087e-05, -5.8573696e-05, -1.5001661e-03, ...,
#        -3.3351549e-05, -2.5888952e-05,  9.0424328e-07], dtype=float32), array([ 1.56165333e-05, -8.32508784e-04, -1.51341185e-02, ...,
#         1.25538662e-07, -1.98333382e-07,  2.34663318e-07], dtype=float32), array([-1.13070400e-05, -1.93581873e-05, -1.01024278e-04, ...,
#        -1.67075013e-05, -1.29314285e-05,  4.57316787e-07], dtype=float32), array([-1.6736318e-05, -9.8340206e-05, -1.4634388e-03, ...,
#        -1.6511254e-05, -1.3143164e-05,  6.5272542e-07], dtype=float32), array([-4.8410848e-06, -2.9720393e-05,  3.7522419e-05, ...,
#        -2.3941305e-07,  3.9657280e-08,  1.0501185e-07], dtype=float32), array([ 1.22112415e-05, -4.80973176e-05, -2.37442990e-04, ...,
#        -2.33063001e-05,  1.94790005e-06,  9.14257043e-08], dtype=float32), array([-1.6448139e-05, -2.0559419e-05, -6.9939240e-05, ...,
#        -2.3864668e-05,  2.2058762e-06,  5.0449785e-08], dtype=float32), array([-1.6501182e-05, -1.0122103e-06,  1.8245906e-05, ...,
#         4.1237286e-08, -3.2695519e-07,  5.8784178e-07], dtype=float32), array([ 1.5181674e-05, -7.7001805e-06, -1.7586586e-05, ...,
#         1.4055945e-06, -1.0009561e-06,  6.6508539e-07], dtype=float32), array([-1.5783646e-05, -4.0872974e-06,  6.0747561e-06, ...,
#        -3.3338823e-05, -2.5897210e-05,  9.0754122e-07], dtype=float32), array([-2.8218110e-05,  2.2852928e-06,  3.7792954e-05, ...,
#         2.0306994e-07, -7.1852824e-08, -4.4275041e-08], dtype=float32), array([ 1.1574090e-06, -1.3264157e-05,  8.2521892e-06, ...,
#        -1.6478923e-05, -1.2912942e-05,  2.3976648e-07], dtype=float32), array([-4.1911087e-05,  1.2884157e-06,  6.8527792e-05, ...,
#        -3.0685652e-07,  9.1631676e-08,  5.7618621e-10], dtype=float32), array([-1.03665225e-05, -7.49589844e-06, -4.75676234e-06, ...,
#        -3.34396318e-05, -2.59072276e-05,  9.87469662e-07], dtype=float32), array([-1.2754978e-05, -1.1996560e-06, -8.2900419e-07, ...,
#        -2.1959877e-05, -2.6932687e-05,  1.1242112e-06], dtype=float32), array([-2.3455166e-06, -1.9984731e-05,  9.0340836e-06, ...,
#        -7.0920828e-07,  4.3111524e-07, -2.9726112e-07], dtype=float32)]

# %%
#Processes the audio waveform in the audio_stimuli list
#The process involves converting the audio files into tensors (As PyTorch deals with Tensors)
inputs = processor(audios=audio_stimuli, return_tensors="pt", padding=True, sampling_rate=48000)

#Inputs the tensors into the CLAP model to extract the audio embeddings
#These embeddings are numerical representations
audio_embeddings = model.get_audio_features(**inputs)

# %%
#Returning dimensions of the tensors
#The 59 is how many audio files there are
#The 512 is the size of any audio embedding
print(audio_embeddings.shape)
# Out:
# torch.Size([59, 512])

# %% [markdown]
# # Process text

# %%
#This is generating the prompts for each section
#We have 2 sections of discrete and dimensional
#Each section has 2 subsections of perceived and induced
discrete_tags = ["happiness", "sadness", "anger", "tenderness", "fear"]

discrete_captions_perceived = ["I perceive this sound as " + tag for tag in discrete_tags]
print(discrete_captions_perceived)
discrete_captions_induced = ["This sound makes me feel " + tag for tag in discrete_tags]
print(discrete_captions_induced)

dimensional_tags = ["positive", "relaxed", "awake"]

dimensional_captions_perceived = ["I perceive this sound as " + tag for tag in dimensional_tags]
print(dimensional_captions_perceived)
dimensional_captions_induced = ["This sound makes me feel " + tag for tag in dimensional_tags]
print(dimensional_captions_induced)
# Out:
# ['I perceive this sound as happiness', 'I perceive this sound as sadness', 'I perceive this sound as anger', 'I perceive this sound as tenderness', 'I perceive this sound as fear']
# ['This sound makes me feel happiness', 'This sound makes me feel sadness', 'This sound makes me feel anger', 'This sound makes me feel tenderness', 'This sound makes me feel fear']
# ['I perceive this sound as positive', 'I perceive this sound as relaxed', 'I perceive this sound as awake']
# ['This sound makes me feel positive', 'This sound makes me feel relaxed', 'This sound makes me feel awake']

# %%
#Combines all the generated text prompts from previous cell into one list
all_tags = discrete_captions_perceived + discrete_captions_induced + dimensional_captions_perceived + dimensional_captions_induced

# NOTE: currently using only dimensional_captions_induced
tag_inputs = processor(text=dimensional_captions_induced, return_tensors="pt", padding=True)
tag_embeds = model.get_text_features(**tag_inputs)

# %% [markdown]
# # Generate outputs

# %%
#Computes the similaity matrix between each audio clip and text tag
#Computes this using dot product between the audio embeddings and text embeddings
sims = torch.matmul(audio_embeddings, tag_embeds.T)
print(sims.shape)
# Out:
# torch.Size([59, 3])

# %% [markdown]
# ## Load csv files and extract related columns

# %%
IDim_positive_path = '/content/Exp1/Data/IDim'
IDim_positive_response_dfs = []

for file in os.listdir(IDim_positive_path):
    if file.endswith(".csv"):
        file_path = os.path.join(IDim_positive_path, file)
        try:
            df = pd.read_csv(file_path, sep=r'\s*,\s*', engine='python')
            # Crucial: Strip whitespace from column names
            df.columns = df.columns.str.strip()

            # Ensure required rating columns exist
            required_cols = ['positive']
            if all(col in df.columns for col in required_cols):
                # Select only the relevant columns and append to our list
                IDim_positive_response_dfs.append(df[required_cols])
            else:
                print(f"Skipping file '{file_path}': Missing required columns ({required_cols}). Found columns: {df.columns.tolist()}")

        except Exception as e:
            print(f"Error reading or processing file {file_path}: {e}")


# Concatenate all individual DataFrames into one master DataFrame for human responses
if IDim_positive_response_dfs:
    master_human_responses_df_positive = pd.concat(IDim_positive_response_dfs, ignore_index=True)
    print(f"Master human responses DataFrame shape: {master_human_responses_df_positive.shape}\n")
    print(f"Master human responses (first 5 rows):\n{master_human_responses_df_positive.head()}\n")
else:
    raise ValueError("No valid CSV files found or processed in IDim_positive_path.")
# Out:
# Master human responses DataFrame shape: (3835, 1)
#
# Master human responses (first 5 rows):
#    positive
# 0      5.24
# 1      4.78
# 2      6.04
# 3      3.36
# 4      4.94

# %%
IDim_relaxed_path = '/content/Exp1/Data/IDim'
IDim_relaxed_response_dfs = []

for file in os.listdir(IDim_relaxed_path):
    if file.endswith(".csv"):
        file_path = os.path.join(IDim_relaxed_path, file)
        try:
            df = pd.read_csv(file_path, sep=r'\s*,\s*', engine='python')
            # Crucial: Strip whitespace from column names
            df.columns = df.columns.str.strip()

            # Ensure required rating columns exist
            required_cols = ['relaxed']
            if all(col in df.columns for col in required_cols):
                # Select only the relevant columns and append to our list
                IDim_relaxed_response_dfs.append(df[required_cols])
            else:
                print(f"Skipping file '{file_path}': Missing required columns ({required_cols}). Found columns: {df.columns.tolist()}")

        except Exception as e:
            print(f"Error reading or processing file {file_path}: {e}")


# Concatenate all individual DataFrames into one master DataFrame for human responses
if IDim_relaxed_response_dfs:
    master_human_responses_df_relaxed = pd.concat(IDim_relaxed_response_dfs, ignore_index=True)
    print(f"Master human responses DataFrame shape: {master_human_responses_df_relaxed.shape}\n")
    print(f"Master human responses (first 5 rows):\n{master_human_responses_df_relaxed.head()}\n")
else:
    raise ValueError("No valid CSV files found or processed in IDim_relaxed_path.")
# Out:
# Master human responses DataFrame shape: (3835, 1)
#
# Master human responses (first 5 rows):
#    relaxed
# 0     5.00
# 1     4.21
# 2     6.35
# 3     5.67
# 4     4.55

# %%
IDim_awake_path = '/content/Exp1/Data/IDim'
IDim_awake_response_dfs = []

for file in os.listdir(IDim_awake_path):
    if file.endswith(".csv"):
        file_path = os.path.join(IDim_awake_path, file)
        try:
            df = pd.read_csv(file_path, sep=r'\s*,\s*', engine='python')
            # Crucial: Strip whitespace from column names
            df.columns = df.columns.str.strip()

            # Ensure required rating columns exist
            required_cols = ['awake']
            if all(col in df.columns for col in required_cols):
                # Select only the relevant columns and append to our list
                IDim_awake_response_dfs.append(df[required_cols])
            else:
                print(f"Skipping file '{file_path}': Missing required columns ({required_cols}). Found columns: {df.columns.tolist()}")

        except Exception as e:
            print(f"Error reading or processing file {file_path}: {e}")


# Concatenate all individual DataFrames into one master DataFrame for human responses
if IDim_awake_response_dfs:
    master_human_responses_df_awake = pd.concat(IDim_awake_response_dfs, ignore_index=True)
    print(f"Master human responses DataFrame shape: {master_human_responses_df_awake.shape}\n")
    print(f"Master human responses (first 5 rows):\n{master_human_responses_df_awake.head()}\n")
else:
    raise ValueError("No valid CSV files found or processed in IDim_awake_path.")
# Out:
# Master human responses DataFrame shape: (3835, 1)
#
# Master human responses (first 5 rows):
#    awake
# 0   5.60
# 1   4.79
# 2   6.34
# 3   4.26
# 4   5.01

# %% [markdown]
# # Prepare features X and targets y

# %%
from sklearn.model_selection import train_test_split


num_participants_positive = len(IDim_positive_response_dfs)
if master_human_responses_df_positive.shape[0] % len(audio_stimuli) != 0:
    print("Warning: Total responses is not a perfect multiple of unique audio files. This might indicate inconsistent data or that not all participants rated all items, which could break implicit ordering.")

X_list_positive = []
for _ in range(num_participants_positive):
    X_list_positive.extend(audio_embeddings.detach()) # Add a full set of embeddings for each participant

# Convert to NumPy array
X_positive = np.array(X_list_positive)

# Extract y from the concatenated DataFrame
y_positive = master_human_responses_df_positive[['positive']].values

print(f"Shape of X (features) after implicit alignment: {X_positive.shape}")
print(f"Shape of y (labels) after implicit alignment: {y_positive.shape}\n")

# Sanity check: X and y must have the same number of rows
if X_positive.shape[0] != y_positive.shape[0]:
    raise ValueError("Number of rows in X and y do not match after implicit alignment. This indicates an issue with the implicit ordering assumption or data loading.")

# --- Split Data into Training and Testing Sets ---

TEST_PERCENTAGE_positive = 0.2  # Adjust as needed
TRAIN_PERCENTAGE_positive = 1 - TEST_PERCENTAGE_positive  # Adjust as needed

X_train_positive, X_test_positive, y_train_positive, y_test_positive = train_test_split(
    X_positive, y_positive, test_size=TEST_PERCENTAGE_positive, random_state=42
)

print(f"Training set size (X_train_positive, y_train_positive): {X_train_positive.shape}, {y_train_positive.shape}")
print(f"Testing set size (X_test_positive, y_test_positive): {X_test_positive.shape}, {y_test_positive.shape}\n")
# Out:
# Shape of X (features) after implicit alignment: (3835, 512)
# Shape of y (labels) after implicit alignment: (3835, 1)
#
# Training set size (X_train_positive, y_train_positive): (3068, 512), (3068, 1)
# Testing set size (X_test_positive, y_test_positive): (767, 512), (767, 1)

# %%
from sklearn.model_selection import train_test_split


num_participants_relaxed = len(IDim_relaxed_response_dfs)
if master_human_responses_df_relaxed.shape[0] % len(audio_stimuli) != 0:
    print("Warning: Total responses is not a perfect multiple of unique audio files. This might indicate inconsistent data or that not all participants rated all items, which could break implicit ordering.")

X_list_relaxed = []
for _ in range(num_participants_relaxed):
    X_list_relaxed.extend(audio_embeddings.detach()) # Add a full set of embeddings for each participant

# Convert to NumPy array
X_relaxed = np.array(X_list_relaxed)

# Extract y from the concatenated DataFrame
y_relaxed = master_human_responses_df_relaxed[['relaxed']].values

print(f"Shape of X (features) after implicit alignment: {X_relaxed.shape}")
print(f"Shape of y (labels) after implicit alignment: {y_relaxed.shape}\n")

# Sanity check: X and y must have the same number of rows
if X_relaxed.shape[0] != y_relaxed.shape[0]:
    raise ValueError("Number of rows in X and y do not match after implicit alignment. This indicates an issue with the implicit ordering assumption or data loading.")

# --- Split Data into Training and Testing Sets ---

TEST_PERCENTAGE_relaxed = 0.2  # Adjust as needed
TRAIN_PERCENTAGE_relaxed = 1 - TEST_PERCENTAGE_relaxed  # Adjust as needed

X_train_relaxed, X_test_relaxed, y_train_relaxed, y_test_relaxed = train_test_split(
    X_relaxed, y_relaxed, test_size=TEST_PERCENTAGE_relaxed, random_state=42
)

print(f"Training set size (X_train_relaxed, y_train_relaxed): {X_train_relaxed.shape}, {y_train_relaxed.shape}")
print(f"Testing set size (X_test_relaxed, y_test_relaxed): {X_test_relaxed.shape}, {y_test_relaxed.shape}\n")
# Out:
# Shape of X (features) after implicit alignment: (3835, 512)
# Shape of y (labels) after implicit alignment: (3835, 1)
#
# Training set size (X_train_relaxed, y_train_relaxed): (3068, 512), (3068, 1)
# Testing set size (X_test_relaxed, y_test_relaxed): (767, 512), (767, 1)

# %%
from sklearn.model_selection import train_test_split


num_participants_awake = len(IDim_awake_response_dfs)
if master_human_responses_df_awake.shape[0] % len(audio_stimuli) != 0:
    print("Warning: Total responses is not a perfect multiple of unique audio files. This might indicate inconsistent data or that not all participants rated all items, which could break implicit ordering.")

X_list_awake = []
for _ in range(num_participants_awake):
    X_list_awake.extend(audio_embeddings.detach()) # Add a full set of embeddings for each participant

# Convert to NumPy array
X_awake = np.array(X_list_awake)

# Extract y from the concatenated DataFrame
y_awake = master_human_responses_df_awake[['awake']].values

print(f"Shape of X (features) after implicit alignment: {X_awake.shape}")
print(f"Shape of y (labels) after implicit alignment: {y_awake.shape}\n")

# Sanity check: X and y must have the same number of rows
if X_awake.shape[0] != y_awake.shape[0]:
    raise ValueError("Number of rows in X and y do not match after implicit alignment. This indicates an issue with the implicit ordering assumption or data loading.")

# --- Split Data into Training and Testing Sets ---

TEST_PERCENTAGE_awake = 0.2  # Adjust as needed
TRAIN_PERCENTAGE_awake = 1 - TEST_PERCENTAGE_awake  # Adjust as needed

X_train_awake, X_test_awake, y_train_awake, y_test_awake = train_test_split(
    X_awake, y_awake, test_size=TEST_PERCENTAGE_awake, random_state=42
)

print(f"Training set size (X_train_awake, y_train_awake): {X_train_awake.shape}, {y_train_awake.shape}")
print(f"Testing set size (X_test_awake, y_test_awake): {X_test_awake.shape}, {y_test_awake.shape}\n")
# Out:
# Shape of X (features) after implicit alignment: (3835, 512)
# Shape of y (labels) after implicit alignment: (3835, 1)
#
# Training set size (X_train_awake, y_train_awake): (3068, 512), (3068, 1)
# Testing set size (X_test_awake, y_test_awake): (767, 512), (767, 1)

# %% [markdown]
# # Train regression head (=MLP, a few projection layers)

# %%
from sklearn.neural_network import MLPRegressor

mlp_regressor_positive = MLPRegressor(
    hidden_layer_sizes=(100, 50),
    activation='relu',
    solver='adam',
    max_iter=1000,
    random_state=42, #Determines random number generation for weights and bias
    verbose=True,
    early_stopping=True,
    n_iter_no_change=50,
    tol=1e-4
)

print("Starting MLP Regressor_positive training...")
mlp_regressor_positive.fit(X_train_positive, y_train_positive)
print("\nMLP Regressor_positive training complete.")
# Out:
# Starting MLP Regressor_positive training...
# Iteration 1, loss = 12.72261545
# Validation score: -4.702067
# Iteration 2, loss = 7.70512113
# Validation score: -1.463984
# Iteration 3, loss = 2.84515621
# Validation score: -0.061137
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1650: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Iteration 4, loss = 1.93240131
# Validation score: 0.178245
# Iteration 5, loss = 1.58192796
# Validation score: 0.193602
# Iteration 6, loss = 1.51326816
# Validation score: 0.236566
# Iteration 7, loss = 1.47760809
# Validation score: 0.241435
# Iteration 8, loss = 1.44908837
# Validation score: 0.249871
# Iteration 9, loss = 1.43150253
# Validation score: 0.255931
# Iteration 10, loss = 1.41774539
# Validation score: 0.261044
# Iteration 11, loss = 1.40722722
# Validation score: 0.265966
# Iteration 12, loss = 1.40098059
# Validation score: 0.268688
# Iteration 13, loss = 1.39731622
# Validation score: 0.273675
# Iteration 14, loss = 1.39158961
# Validation score: 0.275873
# Iteration 15, loss = 1.38729454
# Validation score: 0.280165
# Iteration 16, loss = 1.38461277
# Validation score: 0.282236
# Iteration 17, loss = 1.38093393
# Validation score: 0.279980
# Iteration 18, loss = 1.37861638
# Validation score: 0.285789
# Iteration 19, loss = 1.37541855
# Validation score: 0.283954
# Iteration 20, loss = 1.37275084
# Validation score: 0.286820
# Iteration 21, loss = 1.37290201
# Validation score: 0.286694
# Iteration 22, loss = 1.36997252
# Validation score: 0.286404
# Iteration 23, loss = 1.36914465
# Validation score: 0.288347
# Iteration 24, loss = 1.36762933
# Validation score: 0.290376
# Iteration 25, loss = 1.36647087
# Validation score: 0.285644
# Iteration 26, loss = 1.36632389
# Validation score: 0.291757
# Iteration 27, loss = 1.36587730
# Validation score: 0.290729
# Iteration 28, loss = 1.36209480
# Validation score: 0.290717
# Iteration 29, loss = 1.36331075
# Validation score: 0.289158
# Iteration 30, loss = 1.36208235
# Validation score: 0.296629
# Iteration 31, loss = 1.36032359
# Validation score: 0.287979
# Iteration 32, loss = 1.36093090
# Validation score: 0.294798
# Iteration 33, loss = 1.35844820
# Validation score: 0.291607
# Iteration 34, loss = 1.36327481
# Validation score: 0.297545
# Iteration 35, loss = 1.36238823
# Validation score: 0.298790
# Iteration 36, loss = 1.35929441
# Validation score: 0.300034
# Iteration 37, loss = 1.36100950
# Validation score: 0.288784
# Iteration 38, loss = 1.35482129
# Validation score: 0.301631
# Iteration 39, loss = 1.36121228
# Validation score: 0.291239
# Iteration 40, loss = 1.35716880
# Validation score: 0.295650
# Iteration 41, loss = 1.35742493
# Validation score: 0.300977
# Iteration 42, loss = 1.36014365
# Validation score: 0.290324
# Iteration 43, loss = 1.35386590
# Validation score: 0.298511
# Iteration 44, loss = 1.35559719
# Validation score: 0.297678
# Iteration 45, loss = 1.35533797
# Validation score: 0.297656
# Iteration 46, loss = 1.35882188
# Validation score: 0.296988
# Iteration 47, loss = 1.36178397
# Validation score: 0.305500
# Iteration 48, loss = 1.35504515
# Validation score: 0.292297
# Iteration 49, loss = 1.35386767
# Validation score: 0.299518
# Iteration 50, loss = 1.35265430
# Validation score: 0.297323
# Iteration 51, loss = 1.35191118
# Validation score: 0.300189
# Iteration 52, loss = 1.35411331
# Validation score: 0.290055
# Iteration 53, loss = 1.35442943
# Validation score: 0.301539
# Iteration 54, loss = 1.35534906
# Validation score: 0.304014
# Iteration 55, loss = 1.36040661
# Validation score: 0.298418
# Iteration 56, loss = 1.35817653
# Validation score: 0.293653
# Iteration 57, loss = 1.35182119
# Validation score: 0.303462
# Iteration 58, loss = 1.35438876
# Validation score: 0.301319
# Iteration 59, loss = 1.35303511
# Validation score: 0.300697
# Iteration 60, loss = 1.35297129
# Validation score: 0.294630
# Iteration 61, loss = 1.35594821
# Validation score: 0.297599
# Iteration 62, loss = 1.35020350
# Validation score: 0.299684
# Iteration 63, loss = 1.35058164
# Validation score: 0.297550
# Iteration 64, loss = 1.35482969
# Validation score: 0.305515
# Iteration 65, loss = 1.35069353
# Validation score: 0.298188
# Iteration 66, loss = 1.34863684
# Validation score: 0.302930
# Iteration 67, loss = 1.35083704
# Validation score: 0.298967
# Iteration 68, loss = 1.35264411
# Validation score: 0.303280
# Iteration 69, loss = 1.35121862
# Validation score: 0.306843
# Iteration 70, loss = 1.35306623
# Validation score: 0.289238
# Iteration 71, loss = 1.35543577
# Validation score: 0.303972
# Iteration 72, loss = 1.35050202
# Validation score: 0.307791
# Iteration 73, loss = 1.35124469
# Validation score: 0.296784
# Iteration 74, loss = 1.35033043
# Validation score: 0.306166
# Iteration 75, loss = 1.35014751
# Validation score: 0.307839
# Iteration 76, loss = 1.35147087
# Validation score: 0.306492
# Iteration 77, loss = 1.35259560
# Validation score: 0.284401
# Iteration 78, loss = 1.35120174
# Validation score: 0.310803
# Iteration 79, loss = 1.34849263
# Validation score: 0.302028
# Iteration 80, loss = 1.34886259
# Validation score: 0.302852
# Iteration 81, loss = 1.34957447
# Validation score: 0.307990
# Iteration 82, loss = 1.35245763
# Validation score: 0.298876
# Iteration 83, loss = 1.35146440
# Validation score: 0.299197
# Iteration 84, loss = 1.34919297
# Validation score: 0.308955
# Iteration 85, loss = 1.34960178
# Validation score: 0.308785
# Iteration 86, loss = 1.34922479
# Validation score: 0.287559
# Iteration 87, loss = 1.35098460
# Validation score: 0.309495
# Iteration 88, loss = 1.34964261
# Validation score: 0.306614
# Iteration 89, loss = 1.35103453
# Validation score: 0.308266
# Iteration 90, loss = 1.35461717
# Validation score: 0.306783
# Iteration 91, loss = 1.35033892
# Validation score: 0.297397
# Iteration 92, loss = 1.35246916
# Validation score: 0.311320
# Iteration 93, loss = 1.34872362
# Validation score: 0.295536
# Iteration 94, loss = 1.35484146
# Validation score: 0.306871
# Iteration 95, loss = 1.34794504
# Validation score: 0.304539
# Iteration 96, loss = 1.34872682
# Validation score: 0.307676
# Iteration 97, loss = 1.35392422
# Validation score: 0.305974
# Iteration 98, loss = 1.35284294
# Validation score: 0.290870
# Iteration 99, loss = 1.35739548
# Validation score: 0.276609
# Iteration 100, loss = 1.36304638
# Validation score: 0.311430
# Iteration 101, loss = 1.34993007
# Validation score: 0.307617
# Iteration 102, loss = 1.34982443
# Validation score: 0.306522
# Iteration 103, loss = 1.34967881
# Validation score: 0.304431
# Iteration 104, loss = 1.35124888
# Validation score: 0.306096
# Iteration 105, loss = 1.35091002
# Validation score: 0.306375
# Iteration 106, loss = 1.34941409
# Validation score: 0.306677
# Iteration 107, loss = 1.35107119
# Validation score: 0.312433
# Iteration 108, loss = 1.35241837
# Validation score: 0.300065
# Iteration 109, loss = 1.34918883
# Validation score: 0.296691
# Iteration 110, loss = 1.35181107
# Validation score: 0.312653
# Iteration 111, loss = 1.34876352
# Validation score: 0.302378
# Iteration 112, loss = 1.34933021
# Validation score: 0.309182
# Iteration 113, loss = 1.35632986
# Validation score: 0.310108
# Iteration 114, loss = 1.35288706
# Validation score: 0.311304
# Iteration 115, loss = 1.35797823
# Validation score: 0.302928
# Iteration 116, loss = 1.36009119
# Validation score: 0.293680
# Iteration 117, loss = 1.34875664
# Validation score: 0.303405
# Iteration 118, loss = 1.35375578
# Validation score: 0.310379
# Iteration 119, loss = 1.36045538
# Validation score: 0.315170
# Iteration 120, loss = 1.34708466
# Validation score: 0.271431
# Iteration 121, loss = 1.35648525
# Validation score: 0.308485
# Iteration 122, loss = 1.34712867
# Validation score: 0.309069
# Iteration 123, loss = 1.35183317
# Validation score: 0.288075
# Iteration 124, loss = 1.34909627
# Validation score: 0.310090
# Iteration 125, loss = 1.34864098
# Validation score: 0.305037
# Iteration 126, loss = 1.34944061
# Validation score: 0.297198
# Iteration 127, loss = 1.34830333
# Validation score: 0.313085
# Iteration 128, loss = 1.35041073
# Validation score: 0.308643
# Iteration 129, loss = 1.35616868
# Validation score: 0.312682
# Iteration 130, loss = 1.35199724
# Validation score: 0.308828
# Iteration 131, loss = 1.34870413
# Validation score: 0.308811
# Iteration 132, loss = 1.34502604
# Validation score: 0.281771
# Iteration 133, loss = 1.35391554
# Validation score: 0.307910
# Iteration 134, loss = 1.34787313
# Validation score: 0.312903
# Iteration 135, loss = 1.35274967
# Validation score: 0.299345
# Iteration 136, loss = 1.34687466
# Validation score: 0.310754
# Iteration 137, loss = 1.34879348
# Validation score: 0.314129
# Iteration 138, loss = 1.35510784
# Validation score: 0.291108
# Iteration 139, loss = 1.34796856
# Validation score: 0.305747
# Iteration 140, loss = 1.34764717
# Validation score: 0.309902
# Iteration 141, loss = 1.34568858
# Validation score: 0.304863
# Iteration 142, loss = 1.34533361
# Validation score: 0.310302
# Iteration 143, loss = 1.35346923
# Validation score: 0.305078
# Iteration 144, loss = 1.35119005
# Validation score: 0.303421
# Iteration 145, loss = 1.34582486
# Validation score: 0.311937
# Iteration 146, loss = 1.34824551
# Validation score: 0.289955
# Iteration 147, loss = 1.34697424
# Validation score: 0.313443
# Iteration 148, loss = 1.34676114
# Validation score: 0.289821
# Iteration 149, loss = 1.34633846
# Validation score: 0.311235
# Iteration 150, loss = 1.34998117
# Validation score: 0.310425
# Iteration 151, loss = 1.35514006
# Validation score: 0.298878
# Iteration 152, loss = 1.34986619
# Validation score: 0.300545
# Iteration 153, loss = 1.34881542
# Validation score: 0.299151
# Iteration 154, loss = 1.35862627
# Validation score: 0.315605
# Iteration 155, loss = 1.35167706
# Validation score: 0.301439
# Iteration 156, loss = 1.34973218
# Validation score: 0.308091
# Iteration 157, loss = 1.34929038
# Validation score: 0.312526
# Iteration 158, loss = 1.34996002
# Validation score: 0.285759
# Iteration 159, loss = 1.35197172
# Validation score: 0.302863
# Iteration 160, loss = 1.34817995
# Validation score: 0.300381
# Iteration 161, loss = 1.34710456
# Validation score: 0.311446
# Iteration 162, loss = 1.34818896
# Validation score: 0.309197
# Iteration 163, loss = 1.34670156
# Validation score: 0.302839
# Iteration 164, loss = 1.34973638
# Validation score: 0.292038
# Iteration 165, loss = 1.34994669
# Validation score: 0.305027
# Iteration 166, loss = 1.35059791
# Validation score: 0.310446
# Iteration 167, loss = 1.35081169
# Validation score: 0.305486
# Iteration 168, loss = 1.34512643
# Validation score: 0.303139
# Iteration 169, loss = 1.34803658
# Validation score: 0.308145
# Iteration 170, loss = 1.34792955
# Validation score: 0.306434
# Iteration 171, loss = 1.34581714
# Validation score: 0.312626
# Iteration 172, loss = 1.35042102
# Validation score: 0.305180
# Iteration 173, loss = 1.34827588
# Validation score: 0.299572
# Iteration 174, loss = 1.34511778
# Validation score: 0.310198
# Iteration 175, loss = 1.34779478
# Validation score: 0.307369
# Iteration 176, loss = 1.35008003
# Validation score: 0.311891
# Iteration 177, loss = 1.34572131
# Validation score: 0.302053
# Iteration 178, loss = 1.34788764
# Validation score: 0.300924
# Iteration 179, loss = 1.34805219
# Validation score: 0.289400
# Iteration 180, loss = 1.35257316
# Validation score: 0.303784
# Iteration 181, loss = 1.34698920
# Validation score: 0.285539
# Iteration 182, loss = 1.35412023
# Validation score: 0.313683
# Iteration 183, loss = 1.35231615
# Validation score: 0.310269
# Iteration 184, loss = 1.34674866
# Validation score: 0.312058
# Iteration 185, loss = 1.35038049
# Validation score: 0.307806
# Iteration 186, loss = 1.34733035
# Validation score: 0.305484
# Iteration 187, loss = 1.35027166
# Validation score: 0.290779
# Iteration 188, loss = 1.34652459
# Validation score: 0.309358
# Iteration 189, loss = 1.34631730
# Validation score: 0.307350
# Iteration 190, loss = 1.34728329
# Validation score: 0.302345
# Iteration 191, loss = 1.34478797
# Validation score: 0.312956
# Iteration 192, loss = 1.34714207
# Validation score: 0.299737
# Iteration 193, loss = 1.35210318
# Validation score: 0.295780
# Iteration 194, loss = 1.34768123
# Validation score: 0.302838
# Iteration 195, loss = 1.35321271
# Validation score: 0.310464
# Iteration 196, loss = 1.34698948
# Validation score: 0.313017
# Iteration 197, loss = 1.35018808
# Validation score: 0.312133
# Iteration 198, loss = 1.35579517
# Validation score: 0.306603
# Iteration 199, loss = 1.35378987
# Validation score: 0.302859
# Iteration 200, loss = 1.34770696
# Validation score: 0.304232
# Iteration 201, loss = 1.34912418
# Validation score: 0.293810
# Iteration 202, loss = 1.34787439
# Validation score: 0.311351
# Iteration 203, loss = 1.35066371
# Validation score: 0.297994
# Iteration 204, loss = 1.34556436
# Validation score: 0.302685
# Iteration 205, loss = 1.34796538
# Validation score: 0.308271
# Validation score did not improve more than tol=0.000100 for 50 consecutive epochs. Stopping.
#
# MLP Regressor_positive training complete.

# %%
from sklearn.neural_network import MLPRegressor

mlp_regressor_relaxed = MLPRegressor(
    hidden_layer_sizes=(100, 50),
    activation='relu',
    solver='adam',
    max_iter=1000,
    random_state=42, #Determines random number generation for weights and bias
    verbose=True,
    early_stopping=True,
    n_iter_no_change=50,
    tol=1e-4
)

print("Starting MLP Regressor_relaxed training...")
mlp_regressor_relaxed.fit(X_train_relaxed, y_train_relaxed)
print("\nMLP Regressor_relaxed training complete.")
# Out:
# Starting MLP Regressor_relaxed training...
# Iteration 1, loss = 11.83117368
# Validation score: -3.637644
# Iteration 2, loss = 7.07593221
# Validation score: -0.919648
# Iteration 3, loss = 2.72778035
# Validation score: -0.037343
# Iteration 4, loss = 1.97416178
# Validation score: 0.218441
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1650: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Iteration 5, loss = 1.63037506
# Validation score: 0.257778
# Iteration 6, loss = 1.55200456
# Validation score: 0.288123
# Iteration 7, loss = 1.50841260
# Validation score: 0.306247
# Iteration 8, loss = 1.47718732
# Validation score: 0.318363
# Iteration 9, loss = 1.45722948
# Validation score: 0.326982
# Iteration 10, loss = 1.44293574
# Validation score: 0.332684
# Iteration 11, loss = 1.43283491
# Validation score: 0.337708
# Iteration 12, loss = 1.42584631
# Validation score: 0.341208
# Iteration 13, loss = 1.42240338
# Validation score: 0.343087
# Iteration 14, loss = 1.41797276
# Validation score: 0.345478
# Iteration 15, loss = 1.41325286
# Validation score: 0.346534
# Iteration 16, loss = 1.41387601
# Validation score: 0.345977
# Iteration 17, loss = 1.41106987
# Validation score: 0.348058
# Iteration 18, loss = 1.40486447
# Validation score: 0.349565
# Iteration 19, loss = 1.40129718
# Validation score: 0.351324
# Iteration 20, loss = 1.40137287
# Validation score: 0.351722
# Iteration 21, loss = 1.40196132
# Validation score: 0.349002
# Iteration 22, loss = 1.39652643
# Validation score: 0.351734
# Iteration 23, loss = 1.39781447
# Validation score: 0.353262
# Iteration 24, loss = 1.39344711
# Validation score: 0.352626
# Iteration 25, loss = 1.39038704
# Validation score: 0.353464
# Iteration 26, loss = 1.39099339
# Validation score: 0.354197
# Iteration 27, loss = 1.38977412
# Validation score: 0.353073
# Iteration 28, loss = 1.38983189
# Validation score: 0.352793
# Iteration 29, loss = 1.39002820
# Validation score: 0.354499
# Iteration 30, loss = 1.38948088
# Validation score: 0.352781
# Iteration 31, loss = 1.38680103
# Validation score: 0.352501
# Iteration 32, loss = 1.38795454
# Validation score: 0.353125
# Iteration 33, loss = 1.38327315
# Validation score: 0.353438
# Iteration 34, loss = 1.38482708
# Validation score: 0.354031
# Iteration 35, loss = 1.38751809
# Validation score: 0.352566
# Iteration 36, loss = 1.38342537
# Validation score: 0.352831
# Iteration 37, loss = 1.38301121
# Validation score: 0.354187
# Iteration 38, loss = 1.37878521
# Validation score: 0.350693
# Iteration 39, loss = 1.38756704
# Validation score: 0.354411
# Iteration 40, loss = 1.38168749
# Validation score: 0.351382
# Iteration 41, loss = 1.38326476
# Validation score: 0.342704
# Iteration 42, loss = 1.38852628
# Validation score: 0.350713
# Iteration 43, loss = 1.37841046
# Validation score: 0.354771
# Iteration 44, loss = 1.37608057
# Validation score: 0.353763
# Iteration 45, loss = 1.37804313
# Validation score: 0.349764
# Iteration 46, loss = 1.38762016
# Validation score: 0.351400
# Iteration 47, loss = 1.38321847
# Validation score: 0.352134
# Iteration 48, loss = 1.37632702
# Validation score: 0.354460
# Iteration 49, loss = 1.37775656
# Validation score: 0.354288
# Iteration 50, loss = 1.37451721
# Validation score: 0.354196
# Iteration 51, loss = 1.37564473
# Validation score: 0.352685
# Iteration 52, loss = 1.37737670
# Validation score: 0.353461
# Iteration 53, loss = 1.37467092
# Validation score: 0.353556
# Iteration 54, loss = 1.37641449
# Validation score: 0.351144
# Iteration 55, loss = 1.37340136
# Validation score: 0.353022
# Iteration 56, loss = 1.37832209
# Validation score: 0.353282
# Iteration 57, loss = 1.37708200
# Validation score: 0.353235
# Iteration 58, loss = 1.37302592
# Validation score: 0.352724
# Iteration 59, loss = 1.38020878
# Validation score: 0.352494
# Iteration 60, loss = 1.37201994
# Validation score: 0.353394
# Iteration 61, loss = 1.38081915
# Validation score: 0.348396
# Iteration 62, loss = 1.37480855
# Validation score: 0.353366
# Iteration 63, loss = 1.37262168
# Validation score: 0.353251
# Iteration 64, loss = 1.37284404
# Validation score: 0.352485
# Iteration 65, loss = 1.37100273
# Validation score: 0.348809
# Iteration 66, loss = 1.37070879
# Validation score: 0.351436
# Iteration 67, loss = 1.37541466
# Validation score: 0.352969
# Iteration 68, loss = 1.37032698
# Validation score: 0.354709
# Iteration 69, loss = 1.37138084
# Validation score: 0.354645
# Iteration 70, loss = 1.37147518
# Validation score: 0.352382
# Iteration 71, loss = 1.37407965
# Validation score: 0.351811
# Iteration 72, loss = 1.37032771
# Validation score: 0.350532
# Iteration 73, loss = 1.37440797
# Validation score: 0.347922
# Iteration 74, loss = 1.37233122
# Validation score: 0.350692
# Iteration 75, loss = 1.37377110
# Validation score: 0.352694
# Iteration 76, loss = 1.37283107
# Validation score: 0.349217
# Iteration 77, loss = 1.37131283
# Validation score: 0.352228
# Iteration 78, loss = 1.37223835
# Validation score: 0.352648
# Iteration 79, loss = 1.36918469
# Validation score: 0.351856
# Iteration 80, loss = 1.37003611
# Validation score: 0.352811
# Iteration 81, loss = 1.37062066
# Validation score: 0.349705
# Iteration 82, loss = 1.37598018
# Validation score: 0.350428
# Iteration 83, loss = 1.37314022
# Validation score: 0.351880
# Iteration 84, loss = 1.37403521
# Validation score: 0.348961
# Iteration 85, loss = 1.37249927
# Validation score: 0.353209
# Iteration 86, loss = 1.37125024
# Validation score: 0.350230
# Iteration 87, loss = 1.37344185
# Validation score: 0.352658
# Iteration 88, loss = 1.37197835
# Validation score: 0.352654
# Iteration 89, loss = 1.37208069
# Validation score: 0.351613
# Iteration 90, loss = 1.37421963
# Validation score: 0.353300
# Iteration 91, loss = 1.37021370
# Validation score: 0.347973
# Iteration 92, loss = 1.38022224
# Validation score: 0.353709
# Iteration 93, loss = 1.37015529
# Validation score: 0.352705
# Iteration 94, loss = 1.37016562
# Validation score: 0.353002
# Validation score did not improve more than tol=0.000100 for 50 consecutive epochs. Stopping.
#
# MLP Regressor_relaxed training complete.

# %%
from sklearn.neural_network import MLPRegressor

mlp_regressor_awake = MLPRegressor(
    hidden_layer_sizes=(100, 50),
    activation='relu',
    solver='adam',
    max_iter=1000,
    random_state=42, #Determines random number generation for weights and bias
    verbose=True,
    early_stopping=True,
    n_iter_no_change=50,
    tol=1e-4
)

print("Starting MLP Regressor_awake training...")
mlp_regressor_awake.fit(X_train_awake, y_train_awake)
print("\nMLP Regressor_awake training complete.")
# Out:
# Starting MLP Regressor_awake training...
# Iteration 1, loss = 16.63529883
# Validation score: -7.492959
# Iteration 2, loss = 10.47552155
# Validation score: -2.779072
# Iteration 3, loss = 3.58510799
# Validation score: -0.107331
# Iteration 4, loss = 2.09506068
# Validation score: -0.014619
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1650: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Iteration 5, loss = 1.77700656
# Validation score: 0.076233
# Iteration 6, loss = 1.72395905
# Validation score: 0.126689
# Iteration 7, loss = 1.69841465
# Validation score: 0.138775
# Iteration 8, loss = 1.68449608
# Validation score: 0.144251
# Iteration 9, loss = 1.67637630
# Validation score: 0.146969
# Iteration 10, loss = 1.67266698
# Validation score: 0.147224
# Iteration 11, loss = 1.66796035
# Validation score: 0.153735
# Iteration 12, loss = 1.66375568
# Validation score: 0.154154
# Iteration 13, loss = 1.65824502
# Validation score: 0.155965
# Iteration 14, loss = 1.65656213
# Validation score: 0.153967
# Iteration 15, loss = 1.65294907
# Validation score: 0.157080
# Iteration 16, loss = 1.64863792
# Validation score: 0.156553
# Iteration 17, loss = 1.64790724
# Validation score: 0.157286
# Iteration 18, loss = 1.64560462
# Validation score: 0.158154
# Iteration 19, loss = 1.64360681
# Validation score: 0.155185
# Iteration 20, loss = 1.64318133
# Validation score: 0.162404
# Iteration 21, loss = 1.63902652
# Validation score: 0.157453
# Iteration 22, loss = 1.64176366
# Validation score: 0.156825
# Iteration 23, loss = 1.63784725
# Validation score: 0.157586
# Iteration 24, loss = 1.63530387
# Validation score: 0.158944
# Iteration 25, loss = 1.63593563
# Validation score: 0.160005
# Iteration 26, loss = 1.63470284
# Validation score: 0.155074
# Iteration 27, loss = 1.63340578
# Validation score: 0.154791
# Iteration 28, loss = 1.63182326
# Validation score: 0.157207
# Iteration 29, loss = 1.63041327
# Validation score: 0.156308
# Iteration 30, loss = 1.63219628
# Validation score: 0.154208
# Iteration 31, loss = 1.62911486
# Validation score: 0.155936
# Iteration 32, loss = 1.62883446
# Validation score: 0.156550
# Iteration 33, loss = 1.62740732
# Validation score: 0.155720
# Iteration 34, loss = 1.62656470
# Validation score: 0.154965
# Iteration 35, loss = 1.62797242
# Validation score: 0.150174
# Iteration 36, loss = 1.62669329
# Validation score: 0.150689
# Iteration 37, loss = 1.62662859
# Validation score: 0.152294
# Iteration 38, loss = 1.62690789
# Validation score: 0.149292
# Iteration 39, loss = 1.62539758
# Validation score: 0.150315
# Iteration 40, loss = 1.62475952
# Validation score: 0.147111
# Iteration 41, loss = 1.62532600
# Validation score: 0.149200
# Iteration 42, loss = 1.62586665
# Validation score: 0.148394
# Iteration 43, loss = 1.62613266
# Validation score: 0.149932
# Iteration 44, loss = 1.62459468
# Validation score: 0.149209
# Iteration 45, loss = 1.62323511
# Validation score: 0.148265
# Iteration 46, loss = 1.62338374
# Validation score: 0.146345
# Iteration 47, loss = 1.62526905
# Validation score: 0.142894
# Iteration 48, loss = 1.62711960
# Validation score: 0.140039
# Iteration 49, loss = 1.62524821
# Validation score: 0.144279
# Iteration 50, loss = 1.62217008
# Validation score: 0.149760
# Iteration 51, loss = 1.62093968
# Validation score: 0.145760
# Iteration 52, loss = 1.62379941
# Validation score: 0.140792
# Iteration 53, loss = 1.62171413
# Validation score: 0.142130
# Iteration 54, loss = 1.62509613
# Validation score: 0.141407
# Iteration 55, loss = 1.62248105
# Validation score: 0.146126
# Iteration 56, loss = 1.62074355
# Validation score: 0.142197
# Iteration 57, loss = 1.62270064
# Validation score: 0.139169
# Iteration 58, loss = 1.62268206
# Validation score: 0.141936
# Iteration 59, loss = 1.62373547
# Validation score: 0.139492
# Iteration 60, loss = 1.62308012
# Validation score: 0.140814
# Iteration 61, loss = 1.62212421
# Validation score: 0.143017
# Iteration 62, loss = 1.62188621
# Validation score: 0.136227
# Iteration 63, loss = 1.62109937
# Validation score: 0.138331
# Iteration 64, loss = 1.62353481
# Validation score: 0.142270
# Iteration 65, loss = 1.62422374
# Validation score: 0.138431
# Iteration 66, loss = 1.62548599
# Validation score: 0.137139
# Iteration 67, loss = 1.61876635
# Validation score: 0.140087
# Iteration 68, loss = 1.61993423
# Validation score: 0.139343
# Iteration 69, loss = 1.62060673
# Validation score: 0.137909
# Iteration 70, loss = 1.61993139
# Validation score: 0.137590
# Iteration 71, loss = 1.61857220
# Validation score: 0.139610
# Validation score did not improve more than tol=0.000100 for 50 consecutive epochs. Stopping.
#
# MLP Regressor_awake training complete.

# %% [markdown]
# # Evaluate

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from scipy.stats import pearsonr
import numpy as np

print("Results for IDim – Positive")
print("______________________________________________")

# Predict and reshape if needed
y_pred_positive = mlp_regressor_positive.predict(X_test_positive)
if y_pred_positive.ndim > 1:
    y_pred_positive = y_pred_positive.flatten()
if y_test_positive.ndim > 1:
    y_test_positive = y_test_positive.flatten()

print(f"\nShape of predictions (y_pred): {y_pred_positive.shape}")
print(f"First 5 actual values (y_test):\n{y_test_positive[:5].reshape(-1, 1)}")
print(f"First 5 predicted values (y_pred):\n{y_pred_positive[:5].reshape(-1, 1)}")

print(f"Training/ Test split: {int(TRAIN_PERCENTAGE_positive * 100)}/{int(TEST_PERCENTAGE_positive * 100)}\n")

# Evaluation Metrics
mae_positive = mean_absolute_error(y_test_positive, y_pred_positive)
rmse_positive = np.sqrt(mean_squared_error(y_test_positive, y_pred_positive))
r2_positive = r2_score(y_test_positive, y_pred_positive)


print(f"Mean Absolute Error (MAE): {mae_positive:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_positive:.4f}")
print(f"R-squared (R²): {r2_positive:.4f}")

# Pearson Correlation
if np.std(y_test_positive) > 1e-6 and np.std(y_pred_positive) > 1e-6:
    corr_positive, _ = pearsonr(y_test_positive, y_pred_positive)
    print(f"Pearson Correlation (Relaxed): {corr_positive:.4f}")
else:
    print("Pearson Correlation: Cannot calculate (insufficient variance)")

#Mean Absolute Percentage Error
y_test_positive_safe = np.clip(y_test_positive, a_min=1e-6, a_max=None)
mape_positive = np.mean(np.mean(np.abs((y_test_positive - y_pred_positive) / y_test_positive_safe)) * 100)
print(f"Mean Absolute Percentage Error (MAPE): {mape_positive:.2f}%")
# Out:
# Results for IDim – Positive
# ______________________________________________
#
# Shape of predictions (y_pred): (767,)
# First 5 actual values (y_test):
# [[2.01]
#  [4.06]
#  [1.08]
#  [3.23]
#  [8.02]]
# First 5 predicted values (y_pred):
# [[5.373487 ]
#  [4.6843653]
#  [3.84991  ]
#  [2.9760873]
#  [5.01071  ]]
# Training/ Test split: 80/20
#
# Mean Absolute Error (MAE): 1.3856
# Root Mean Squared Error (RMSE): 1.7381
# R-squared (R²): 0.3145
# Pearson Correlation (Relaxed): 0.5635
# Mean Absolute Percentage Error (MAPE): 45.99%

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from scipy.stats import pearsonr
import numpy as np

print("Results for IDim – Relaxed")
print("______________________________________________")

# Predict and reshape if needed
y_pred_relaxed = mlp_regressor_relaxed.predict(X_test_relaxed)
if y_pred_relaxed.ndim > 1:
    y_pred_relaxed = y_pred_relaxed.flatten()
if y_test_relaxed.ndim > 1:
    y_test_relaxed = y_test_relaxed.flatten()

print(f"\nShape of predictions (y_pred): {y_pred_relaxed.shape}")
print(f"First 5 actual values (y_test):\n{y_test_relaxed[:5].reshape(-1, 1)}")
print(f"First 5 predicted values (y_pred):\n{y_pred_relaxed[:5].reshape(-1, 1)}")

print(f"Training/ Test split: {int(TRAIN_PERCENTAGE_relaxed * 100)}/{int(TEST_PERCENTAGE_relaxed * 100)}\n")

# Evaluation Metrics
mae_relaxed = mean_absolute_error(y_test_relaxed, y_pred_relaxed)
rmse_relaxed = np.sqrt(mean_squared_error(y_test_relaxed, y_pred_relaxed))
r2_relaxed = r2_score(y_test_relaxed, y_pred_relaxed)

print(f"Mean Absolute Error (MAE): {mae_relaxed:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_relaxed:.4f}")
print(f"R-squared (R²): {r2_relaxed:.4f}")

# Pearson Correlation
if np.std(y_test_relaxed) > 1e-6 and np.std(y_pred_relaxed) > 1e-6:
    corr_relaxed, _ = pearsonr(y_test_relaxed, y_pred_relaxed)
    print(f"Pearson Correlation (Relaxed): {corr_relaxed:.4f}")
else:
    print("Pearson Correlation: Cannot calculate (insufficient variance)")

#Mean Absolute Percentage Error
y_test_relaxed_safe = np.clip(y_test_relaxed, a_min=1e-6, a_max=None)
mape_relaxed = np.mean(np.mean(np.abs((y_test_relaxed - y_pred_relaxed) / y_test_relaxed_safe)) * 100)
print(f"Mean Absolute Percentage Error (MAPE): {mape_relaxed:.2f}%")
# Out:
# Results for IDim – Relaxed
# ______________________________________________
#
# Shape of predictions (y_pred): (767,)
# First 5 actual values (y_test):
# [[4.93]
#  [3.06]
#  [1.02]
#  [1.  ]
#  [8.02]]
# First 5 predicted values (y_pred):
# [[5.3601756]
#  [4.666016 ]
#  [3.2587814]
#  [2.1517289]
#  [4.788669 ]]
# Training/ Test split: 80/20
#
# Mean Absolute Error (MAE): 1.4343
# Root Mean Squared Error (RMSE): 1.7671
# R-squared (R²): 0.3342
# Pearson Correlation (Relaxed): 0.5811
# Mean Absolute Percentage Error (MAPE): 44.69%

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from scipy.stats import pearsonr
import numpy as np

print("Results for IDim – Awake")
print("______________________________________________")

# Predict and reshape if needed
y_pred_awake = mlp_regressor_awake.predict(X_test_awake)
if y_pred_awake.ndim > 1:
    y_pred_awake = y_pred_awake.flatten()
if y_test_awake.ndim > 1:
    y_test_awake = y_test_awake.flatten()

print(f"\nShape of predictions (y_pred): {y_pred_awake.shape}")
print(f"First 5 actual values (y_test):\n{y_test_awake[:5].reshape(-1, 1)}")
print(f"First 5 predicted values (y_pred):\n{y_pred_awake[:5].reshape(-1, 1)}")

print(f"Training/ Test split: {int(TRAIN_PERCENTAGE_awake * 100)}/{int(TEST_PERCENTAGE_awake * 100)}\n")

# Evaluation Metrics
mae_awake = mean_absolute_error(y_test_awake, y_pred_awake)
rmse_awake = np.sqrt(mean_squared_error(y_test_awake, y_pred_awake))
r2_awake = r2_score(y_test_awake, y_pred_awake)

print(f"Mean Absolute Error (MAE): {mae_awake:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse_awake:.4f}")
print(f"R-squared (R²): {r2_awake:.4f}")

# Pearson Correlation
if np.std(y_test_awake) > 1e-6 and np.std(y_pred_awake) > 1e-6:
    corr_awake, _ = pearsonr(y_test_awake, y_pred_awake)
    print(f"Pearson Correlation (awake): {corr_awake:.4f}")
else:
    print("Pearson Correlation: Cannot calculate (insufficient variance)")

#Mean Absolute Percentage Error
y_test_awake_safe = np.clip(y_test_awake, a_min=1e-6, a_max=None)
mape_awake = np.mean(np.mean(np.abs((y_test_awake - y_pred_awake) / y_test_awake_safe)) * 100)
print(f"Mean Absolute Percentage Error (MAPE): {mape_awake:.2f}%")
# Out:
# Results for IDim – Awake
# ______________________________________________
#
# Shape of predictions (y_pred): (767,)
# First 5 actual values (y_test):
# [[1.96]
#  [2.92]
#  [9.  ]
#  [6.9 ]
#  [7.03]]
# First 5 predicted values (y_pred):
# [[4.745537 ]
#  [4.784462 ]
#  [6.714811 ]
#  [7.0741386]
#  [5.970946 ]]
# Training/ Test split: 80/20
#
# Mean Absolute Error (MAE): 1.4946
# Root Mean Squared Error (RMSE): 1.9015
# R-squared (R²): 0.0578
# Pearson Correlation (awake): 0.2516
# Mean Absolute Percentage Error (MAPE): 39.77%

# %%
# Organize metrics into a dictionary
print("Results for Dimensional Induced (IDim)")
print("______________________________________________")
data = {
    "Dimension": ["Positive", "Relaxed", "Awake"],
    "MAE": [mae_positive, mae_relaxed, mae_awake],
    "RMSE": [rmse_positive, rmse_relaxed, rmse_awake],
    "R²": [r2_positive, r2_relaxed, r2_awake],
    "Pearson Corr.": [corr_positive, corr_relaxed, corr_awake],
    "MAPE": [mape_positive, mape_relaxed, mape_awake]
}

# Create DataFrame
df_metrics = pd.DataFrame(data)

# Add average row
avg_row = {
    "Dimension": "Average",
    "MAE": df_metrics["MAE"].mean(),
    "RMSE": df_metrics["RMSE"].mean(),
    "R²": df_metrics["R²"].mean(),
    "Pearson Corr.": df_metrics["Pearson Corr."].mean(),
    "MAPE": df_metrics["MAPE"].mean()
}
df_metrics = pd.concat([df_metrics, pd.DataFrame([avg_row])], ignore_index=True)


# Display
print(df_metrics.round(4))
# Out:
# Results for Dimensional Induced (IDim)
# ______________________________________________
#   Dimension     MAE    RMSE      R²  Pearson Corr.     MAPE
# 0  Positive  1.3856  1.7381  0.3145         0.5635  45.9882
# 1   Relaxed  1.4343  1.7671  0.3342         0.5811  44.6924
# 2     Awake  1.4946  1.9015  0.0578         0.2516  39.7662
# 3   Average  1.4382  1.8022  0.2355         0.4654  43.4823
